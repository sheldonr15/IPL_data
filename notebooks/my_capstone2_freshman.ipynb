# %%
from sheets import data, headers
import pandas as pd
import plotly.express as px

# %%
# dff = pd.DataFrame(data, columns=headers)
df = pd.read_csv("../data/matches.csv")

# %% [markdown]
# ## Graph Number of wins per season by each team

# %% [markdown]
# ### Plot(line graph): x : season ; y : wins ; color : team
#
# ####

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
# id                 756 non-null int64
# season             756 non-null int64
# city               749 non-null object
# date               756 non-null object
# team1              756 non-null object
# team2              756 non-null object
# toss_winner        756 non-null object
# toss_decision      756 non-null object
# result             756 non-null object
# dl_applied         756 non-null int64
# winner             752 non-null object
# win_by_runs        756 non-null int64
# win_by_wickets     756 non-null int64
# player_of_match    752 non-null object
# venue              756 non-null object
# umpire1            754 non-null object
# umpire2            754 non-null object
# umpire3            119 non-null object
# dtypes: int64(5), object(13)
# memory usage: 106.4+ KB

# %%
df.loc[df["city"].isna()]
# Out:
#       id  season city       date                        team1  \
# 461  462    2014  NaN 2014-04-19               Mumbai Indians
# 462  463    2014  NaN 2014-04-19        Kolkata Knight Riders
# 466  467    2014  NaN 2014-04-23          Chennai Super Kings
# 468  469    2014  NaN 2014-04-25          Sunrisers Hyderabad
# 469  470    2014  NaN 2014-04-25               Mumbai Indians
# 474  475    2014  NaN 2014-04-28  Royal Challengers Bangalore
# 476  477    2014  NaN 2014-04-30          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 461  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 462             Delhi Daredevils        Kolkata Knight Riders           bat
# 466             Rajasthan Royals             Rajasthan Royals         field
# 468             Delhi Daredevils          Sunrisers Hyderabad           bat
# 469          Chennai Super Kings               Mumbai Indians           bat
# ...

# %% [markdown]
# ### Cleaning

# %%
df["city"] = df["city"].fillna("Dubai")
df["team1"] = df["team1"].replace("Rising Pune Supergiants", "Rising Pune Supergiant")
df["team2"] = df["team2"].replace("Rising Pune Supergiants", "Rising Pune Supergiant")
df["winner"] = df["winner"].replace("Rising Pune Supergiants", "Rising Pune Supergiant")
df["city"] = df["city"].replace("Bangalore", "Bengaluru")

# %%
df.loc[df["winner"].isna()]
# Out:
#         id  season       city       date                        team1  \
# 300    301    2011      Delhi 2011-05-21             Delhi Daredevils
# 545    546    2015  Bengaluru 2015-04-29  Royal Challengers Bangalore
# 570    571    2015  Bengaluru 2015-05-17             Delhi Daredevils
# 744  11340    2019  Bengaluru 2019-04-30  Royal Challengers Bangalore
#
#                            team2                  toss_winner toss_decision  \
# 300                Pune Warriors             Delhi Daredevils           bat
# 545             Rajasthan Royals             Rajasthan Royals         field
# 570  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 744             Rajasthan Royals             Rajasthan Royals         field
#
#         result  dl_applied winner  win_by_runs  win_by_wickets  \
# 300  no result           0    NaN            0               0
# 545  no result           0    NaN            0               0
# ...

# %%
df["season"].value_counts(ascending=True)
# Out:
# 2009    57
# 2008    58
# 2015    59
# 2017    59
# 2010    60
# 2014    60
# 2016    60
# 2018    60
# 2019    60
# 2011    73
# 2012    74
# 2013    76
# Name: season, dtype: int64

# %%
'''
2008 : 59 / 58
2009 : 59 / 57
2010 : 60 
2011 : 74 / 73
2012 : 76 / 74
2013 : 76 
2014 : 60 
2015 : 60 / 59 
2016 : 60 
2017 : 60 / 59
2018 : 60 
2019 : 60

2008 : 2008-05-22

'''
# Out:
# '\n2008 : 59 / 58\n2009 : 59 / 57\n2010 : 60 \n2011 : 74 / 73\n2012 : 76 / 74\n2013 : 76 \n2014 : 60 \n2015 : 60 / 59 \n2016 : 60 \n2017 : 60 / 59\n2018 : 60 \n2019 : 60\n\n2008 : 2008-05-22\n\n'

# %%
# df.loc[df["season"]==2009]

# %%
df["date"].dtypes
# Out:
# dtype('<M8[ns]')

# %%
# df["date"] = [time.date() for time in df["date"]]
# df["date"] = pd.to_datetime(df["date"])

# %%
# df.loc[df["season"]==2008].sort_values(by=["date"])

# %%
values_of_datee = df.loc[df["season"]==2009]
# line = {"A" : 1, "B" : 2}
# line_df = pd.DataFrame(line, index=[3])
# demo_df = pd.concat([demo_df.iloc[:2], line_df, demo_df.iloc[2:]], ignore_index=True)
# Here, loc returned series (df["date"]) for which the .sort_values( ) doesnt require a "by=" parameter

# %%
values_of_date = values_of_datee.sort_values(by=["date"])

# %%
values_of_datee.shape
# Out:
# (57, 18)

# %%
# date_list = []
values_of_date[["date", "team1"]][:35]
# (2008)22 - 04
# (2009)21 - 04 : 25 - 04
# (2011)19 - 04 :
# (2012)24 - 04 : 25 - 04
# (2015)26 - 04
# (2017)25 - 04
# Out:
#           date                        team1
# 117 2009-04-18               Mumbai Indians
# 118 2009-04-18  Royal Challengers Bangalore
# 119 2009-04-19              Kings XI Punjab
# 120 2009-04-19        Kolkata Knight Riders
# 121 2009-04-20          Chennai Super Kings
# 122 2009-04-21              Kings XI Punjab
# 123 2009-04-22              Deccan Chargers
# 124 2009-04-23             Delhi Daredevils
# 125 2009-04-23             Rajasthan Royals
# 126 2009-04-24  Royal Challengers Bangalore
# 127 2009-04-25              Deccan Chargers
# 128 2009-04-26  Royal Challengers Bangalore
# 129 2009-04-26              Kings XI Punjab
# 131 2009-04-27               Mumbai Indians
# 130 2009-04-27          Chennai Super Kings
# 132 2009-04-28             Delhi Daredevils
# 133 2009-04-29        Kolkata Knight Riders
# 134 2009-04-29              Kings XI Punjab
# 135 2009-04-30              Deccan Chargers
# 136 2009-04-30          Chennai Super Kings
# ...

# %%
len(date_list)
# date_list.pop()
# Out:
# 59

# %%
# values_of_date["date_list"] = date_list

# %%
# values_of_date[["date", "date_list"]]

# %%
# values_of_date.columns

# %%
# values_of_date["date"].dtypes

# %%
# ADDING ROW IN BETWEEN DATAFRAME USING INDEX

# demo_dict = {"A" : [1, 2, 3, 4], "B" : [1, 2, 3, 4]}
# demo_df = pd.DataFrame(demo_dict)
# demo_df

# line = {"A" : 1, "B" : 2}
# line_df = pd.DataFrame(line, index=[3])
# demo_df = pd.concat([demo_df.iloc[:2], line_df, demo_df.iloc[2:]], ignore_index=True)
# demo_df

# %%
# FIND INDEX USING VALUE OF "id"

# indeex = df.index[df["id"]==60]
# indeex

# %%
values_of_datee["umpire3"].value_counts()
# Out:
# Series([], Name: umpire3, dtype: int64)

# %%
# add_2008 = 
# {
#     "season" : 2008
#     "city" : "Delhi"
#     "date" : 2008-05-22
#     "team1" : "Delhi Daredevils"
#     "team2" : "Kolkata Knight Riders"
#     "toss_winner" : ""
#     "toss_decision" :
#     "result" : "no result"
#     "dl_applied" : 0
#     "winner" : ""
#     "win_by_runs" : 
#     "win_by_wickets" :
#     "player_of_match" :
#     "venue" : "Arun Jaitley Stadium"
#     "umpire1" : "AV Jayaprakash"
#     "umpire2" : "BG Jerling"
#     "umpire3" : ""
# }
# add_2009 = 
# {
#     "season" : 2009
#     "city" : "Delhi"
#     "date" : 2008-05-22
#     "team1" : "Delhi Daredevils"
#     "team2" : "Kolkata Knight Riders"
#     "toss_winner" : ""
#     "toss_decision" :
#     "result" : "no result"
#     "dl_applied" : 0
#     "winner" : ""
#     "win_by_runs" : 
#     "win_by_wickets" :
#     "player_of_match" :
#     "venue" : "Arun Jaitley Stadium"
#     "umpire1" : "AV Jayaprakash"
#     "umpire2" : "BG Jerling"
#     "umpire3" : ""
# }
# add_2011 = {}
# add_2012 = {}
# add_2015 = {}
# add_2017 = {}
